# %% [markdown]
# <a href="https://colab.research.google.com/github/MasterChefJR/AprendeConAlfEjerciciosResueltos/blob/main/EjercicioDatoSimple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio 1
# Escribir un programa que muestre por pantalla la cadena ¡Hola Mundo!.

# %%
print("Hola Mundo")
# Out:
# Hola Mundo
